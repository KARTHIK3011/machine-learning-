# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/My Drive/try1.csv')
df
# Out:
#    Unnamed: 0       city name rank  score
# 0           0      assam    a  1st     45
# 1           1  bangalore    b  2nd     54
# 2           2    chennai    c  3rd     65
# 3           3   dehradun    d  4th     56

# %%
df=df.drop(columns=["Unnamed: 0"])

# %%
df
# Out:
#         city name rank  score
# 0      assam    a  1st     45
# 1  bangalore    b  2nd     54
# 2    chennai    c  3rd     65
# 3   dehradun    d  4th     56

# %%
df.head
# Out:
# <bound method NDFrame.head of         city name rank  score
# 0      assam    a  1st     45
# 1  bangalore    b  2nd     54
# 2    chennai    c  3rd     65
# 3   dehradun    d  4th     56>

# %%
df.head()
# Out:
#         city name rank  score
# 0      assam    a  1st     45
# 1  bangalore    b  2nd     54
# 2    chennai    c  3rd     65
# 3   dehradun    d  4th     56

# %%
df.head(2)
# Out:
#         city name rank  score
# 0      assam    a  1st     45
# 1  bangalore    b  2nd     54

# %%
df.tail()
# Out:
#         city name rank  score
# 0      assam    a  1st     45
# 1  bangalore    b  2nd     54
# 2    chennai    c  3rd     65
# 3   dehradun    d  4th     56

# %%
df.tail(3)
# Out:
#         city name rank  score
# 1  bangalore    b  2nd     54
# 2    chennai    c  3rd     65
# 3   dehradun    d  4th     56

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (4, 4)

# %%
df.size
# Out:
# 16

# %%
df.columns
# Out:
# Index(['city', 'name', 'rank', 'score'], dtype='object')

# %%
df['name']
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# Name: name, dtype: object

# %%
df["sports"]=["A","B","C","D"]
df
# Out:
#         city name rank  score sports
# 0      assam    a  1st     45      A
# 1  bangalore    b  2nd     54      B
# 2    chennai    c  3rd     65      C
# 3   dehradun    d  4th     56      D

# %%
df.insert(2,column="sport1",value="cricket")
df
# Out:
#         city name   sport1 rank  score sports
# 0      assam    a  cricket  1st     45      A
# 1  bangalore    b  cricket  2nd     54      B
# 2    chennai    c  cricket  3rd     65      C
# 3   dehradun    d  cricket  4th     56      D

# %%
df.loc[2]
# Out:
# city      chennai
# name            c
# sport1    cricket
# rank          3rd
# score          65
# sports          C
# Name: 2, dtype: object

# %%
df.loc[1:3]
# Out:
#         city name   sport1 rank  score sports
# 1  bangalore    b  cricket  2nd     54      B
# 2    chennai    c  cricket  3rd     65      C
# 3   dehradun    d  cricket  4th     56      D

# %%
df.loc[0:3:2]
# Out:
#       city name   sport1 rank  score sports
# 0    assam    a  cricket  1st     45      A
# 2  chennai    c  cricket  3rd     65      C

# %%
df.sample()
# Out:
#     city name   sport1 rank  score sports
# 0  assam    a  cricket  1st     45      A

# %%
df.sample()
# Out:
#         city name   sport1 rank  score sports
# 1  bangalore    b  cricket  2nd     54      B

# %%
df.sample(n=2)
# Out:
#         city name   sport1 rank  score sports
# 2    chennai    c  cricket  3rd     65      C
# 1  bangalore    b  cricket  2nd     54      B

# %%
df.sample(frac=.5)
# Out:
#        city name   sport1 rank  score sports
# 2   chennai    c  cricket  3rd     65      C
# 3  dehradun    d  cricket  4th     56      D

# %%
df.sample(frac=.25)
# Out:
#     city name   sport1 rank  score sports
# 0  assam    a  cricket  1st     45      A

# %%
df.sample(n=2,axis=1)
# Out:
#   rank       city
# 0  1st      assam
# 1  2nd  bangalore
# 2  3rd    chennai
# 3  4th   dehradun

# %%
df.sample(frac=.5,axis=1)
# Out:
#         city sports name
# 0      assam      A    a
# 1  bangalore      B    b
# 2    chennai      C    c
# 3   dehradun      D    d

# %%
cars=pd.read_csv('/content/drive/My Drive/mtcars.csv')
cars
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...

# %%
cars=pd.read_csv('/content/drive/My Drive/mtcars.csv',index_col='hp')
cars.sort_index(inplace=True)
cars
# Out:
#                    model   mpg  cyl   disp  drat  ...   qsec  vs  am  gear  carb
# hp                                                ...
# 52           Honda Civic  30.4    4   75.7  4.93  ...  18.52   1   1     4     2
# 62             Merc 240D  24.4    4  146.7  3.69  ...  20.00   1   0     4     2
# 65        Toyota Corolla  33.9    4   71.1  4.22  ...  19.90   1   1     4     1
# 66             Fiat X1-9  27.3    4   79.0  4.08  ...  18.90   1   1     4     1
# 66              Fiat 128  32.4    4   78.7  4.08  ...  19.47   1   1     4     1
# 91         Porsche 914-2  26.0    4  120.3  4.43  ...  16.70   0   1     5     2
# 93            Datsun 710  22.8    4  108.0  3.85  ...  18.61   1   1     4     1
# 95              Merc 230  22.8    4  140.8  3.92  ...  22.90   1   0     4     2
# 97         Toyota Corona  21.5    4  120.1  3.70  ...  20.01   1   0     3     1
# 105              Valiant  18.1    6  225.0  2.76  ...  20.22   1   0     3     1
# ...

# %%
cars=pd.read_csv('/content/drive/My Drive/mtcars.csv',index_col='model')
cars.sort_index(inplace=True)
cars
# Out:
#                       mpg  cyl   disp   hp  drat  ...   qsec  vs  am  gear  carb
# model                                             ...
# Mazda RX4            21.0    6  160.0  110  3.90  ...  16.46   0   1     4     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  ...  17.02   0   1     4     4
# Datsun 710           22.8    4  108.0   93  3.85  ...  18.61   1   1     4     1
# Hornet 4 Drive       21.4    6  258.0  110  3.08  ...  19.44   1   0     3     1
# Hornet Sportabout    18.7    8  360.0  175  3.15  ...  17.02   0   0     3     2
# Valiant              18.1    6  225.0  105  2.76  ...  20.22   1   0     3     1
# Duster 360           14.3    8  360.0  245  3.21  ...  15.84   0   0     3     4
# Merc 240D            24.4    4  146.7   62  3.69  ...  20.00   1   0     4     2
# Merc 230             22.8    4  140.8   95  3.92  ...  22.90   1   0     4     2
# Merc 280             19.2    6  167.6  123  3.92  ...  18.30   1   0     4     4
# ...

# %%
cars=pd.read_csv('/content/drive/My Drive/mtcars.csv',index_col='disp')
cars.sort_index(inplace=True)
cars
# Out:
#                      model   mpg  cyl   hp  drat  ...   qsec  vs  am  gear  carb
# disp                                              ...
# 71.1        Toyota Corolla  33.9    4   65  4.22  ...  19.90   1   1     4     1
# 75.7           Honda Civic  30.4    4   52  4.93  ...  18.52   1   1     4     2
# 78.7              Fiat 128  32.4    4   66  4.08  ...  19.47   1   1     4     1
# 79.0             Fiat X1-9  27.3    4   66  4.08  ...  18.90   1   1     4     1
# 95.1          Lotus Europa  30.4    4  113  3.77  ...  16.90   1   1     5     2
# 108.0           Datsun 710  22.8    4   93  3.85  ...  18.61   1   1     4     1
# 120.1        Toyota Corona  21.5    4   97  3.70  ...  20.01   1   0     3     1
# 120.3        Porsche 914-2  26.0    4   91  4.43  ...  16.70   0   1     5     2
# 121.0           Volvo 142E  21.4    4  109  4.11  ...  18.60   1   1     4     2
# 140.8             Merc 230  22.8    4   95  3.92  ...  22.90   1   0     4     2
# ...

# %%
cars.describe()
# Out:
#              mpg        cyl          hp  ...         am       gear     carb
# count  32.000000  32.000000   32.000000  ...  32.000000  32.000000  32.0000
# mean   20.090625   6.187500  146.687500  ...   0.406250   3.687500   2.8125
# std     6.026948   1.785922   68.562868  ...   0.498991   0.737804   1.6152
# min    10.400000   4.000000   52.000000  ...   0.000000   3.000000   1.0000
# 25%    15.425000   4.000000   96.500000  ...   0.000000   3.000000   2.0000
# 50%    19.200000   6.000000  123.000000  ...   0.000000   4.000000   2.0000
# 75%    22.800000   8.000000  180.000000  ...   1.000000   4.000000   4.0000
# max    33.900000   8.000000  335.000000  ...   1.000000   5.000000   8.0000
#
# [8 rows x 10 columns]

# %%
cars=pd.read_csv('/content/drive/My Drive/mtcars.csv')
cars
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...

# %%
cars=pd.read_csv('/content/drive/My Drive/mtcars.csv',index_col='model')
cars.sort_index(inplace=True)
cars
# Out:
#                       mpg  cyl   disp   hp  drat  ...   qsec  vs  am  gear  carb
# model                                             ...
# AMC Javelin          15.2    8  304.0  150  3.15  ...  17.30   0   0     3     2
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  ...  17.98   0   0     3     4
# Camaro Z28           13.3    8  350.0  245  3.73  ...  15.41   0   0     3     4
# Chrysler Imperial    14.7    8  440.0  230  3.23  ...  17.42   0   0     3     4
# Datsun 710           22.8    4  108.0   93  3.85  ...  18.61   1   1     4     1
# Dodge Challenger     15.5    8  318.0  150  2.76  ...  16.87   0   0     3     2
# Duster 360           14.3    8  360.0  245  3.21  ...  15.84   0   0     3     4
# Ferrari Dino         19.7    6  145.0  175  3.62  ...  15.50   0   1     5     6
# Fiat 128             32.4    4   78.7   66  4.08  ...  19.47   1   1     4     1
# Fiat X1-9            27.3    4   79.0   66  4.08  ...  18.90   1   1     4     1
# ...

# %%
cars.loc["Dodge Challenger"]
# Out:
# mpg      15.50
# cyl       8.00
# disp    318.00
# hp      150.00
# drat      2.76
# wt        3.52
# qsec     16.87
# vs        0.00
# am        0.00
# gear      3.00
# carb      2.00
# Name: Dodge Challenger, dtype: float64

# %%
cars.iloc[5]
# Out:
# mpg      15.50
# cyl       8.00
# disp    318.00
# hp      150.00
# drat      2.76
# wt        3.52
# qsec     16.87
# vs        0.00
# am        0.00
# gear      3.00
# carb      2.00
# Name: Dodge Challenger, dtype: float64

# %%
cars.loc["Dodge Challenger","hp"]
# Out:
# 150

# %%
cars.iloc[5,3]
# Out:
# 150

# %%
cars.loc["Dodge Challenger","mpg":"hp"]
# Out:
# mpg      15.5
# cyl       8.0
# disp    318.0
# hp      150.0
# Name: Dodge Challenger, dtype: float64

# %%
cars.iloc[5, 0:4]
# Out:
# mpg      15.5
# cyl       8.0
# disp    318.0
# hp      150.0
# Name: Dodge Challenger, dtype: float64

# %%
df=pd.read_csv('/content/drive/My Drive/Titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.head(15)
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0             1         0       3  ...   7.2500   NaN         S
# 1             2         1       1  ...  71.2833   C85         C
# 2             3         1       3  ...   7.9250   NaN         S
# 3             4         1       1  ...  53.1000  C123         S
# 4             5         0       3  ...   8.0500   NaN         S
# 5             6         0       3  ...   8.4583   NaN         Q
# 6             7         0       1  ...  51.8625   E46         S
# 7             8         0       3  ...  21.0750   NaN         S
# 8             9         1       3  ...  11.1333   NaN         S
# 9            10         1       2  ...  30.0708   NaN         C
# 10           11         1       3  ...  16.7000    G6         S
# 11           12         1       1  ...  26.5500  C103         S
# 12           13         0       3  ...   8.0500   NaN         S
# 13           14         0       3  ...  31.2750   NaN         S
# ...

# %%
df.tail(15)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 876          877         0       3  ...   9.8458   NaN         S
# 877          878         0       3  ...   7.8958   NaN         S
# 878          879         0       3  ...   7.8958   NaN         S
# 879          880         1       1  ...  83.1583   C50         C
# 880          881         1       2  ...  26.0000   NaN         S
# 881          882         0       3  ...   7.8958   NaN         S
# 882          883         0       3  ...  10.5167   NaN         S
# 883          884         0       2  ...  10.5000   NaN         S
# 884          885         0       3  ...   7.0500   NaN         S
# 885          886         0       3  ...  29.1250   NaN         Q
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
import numpy as np
Survived_people = df["Survived"].values
unique,count_values = np.unique(Survived_people, return_counts = True)
print(f'not survived:{count_values[0]}')
print(f'survived:{count_values[1]}')
# Out:
# not survived:549
# survived:342

# %%
import matplotlib.pyplot as plt
label=("survived","not survived")
plt.bar(label,count_values,color=['r','g'])
plt.show
# Out:
# <function matplotlib.pyplot.show>
